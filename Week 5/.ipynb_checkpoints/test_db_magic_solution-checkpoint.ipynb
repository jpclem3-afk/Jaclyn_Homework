# %% [markdown]
# # 🪄 Introduction to Magic Commands in Jupyter
#
# **Magic commands** (or **IPython magics**) are special shorthand shortcuts built into the Jupyter notebook kernel that extend its core capabilities. They allow you to control your notebook's environment, interact with your computer's operating system, and run code in other languages (like SQL or Bash) without leaving your Python environment.
#
# Magic commands always begin with a percent sign (`%`) and are divided into two main categories:
#
# ---
#
# ### 1. Line Magics (`%`)
# Line magics operate on **a single line of code only**. Anything else typed on the lines below them will be treated as standard Python.
#
# * `%load_ext sql`: Loads an external extension (like the SQL toolset).
# * `%pip install pandas`: Installs a library to your current notebook environment without needing to open a separate terminal.
# * `%pwd`: Prints the current working directory path of your notebook.
#
# ---
#
# ### 2. Cell Magics (`%%`)
# Cell magics operate on the **entire notebook cell**. The magic command **must** be placed at the absolute top of the cell (Line 1); otherwise, Jupyter will throw a syntax error.
#
# * `%%sql`: Converts the entire cell into an active SQL editor window, allowing you to run database queries directly against a connected database file.
# * `%%timeit`: Runs the code inside the cell multiple times and calculates the exact average execution speed (ideal for testing data processing performance).
# * `%%bash`: Runs script commands directly inside your operating system's terminal shell wrapper.
#
# ---
#
# ### 🎯 Why They Are Crucial for Data Analytics
#
# Without magic commands, connecting a Jupyter notebook to a database engine like SQLite requires writing repetitive Python boilerplate code (`sqlite3.connect`, creating cursors, and wrapping queries inside text strings).
#
# By using the combination of `%load_ext sql` and `%%sql`, you turn your data notebook into a **direct database terminal console**, letting you quickly prototype schemas and test queries on the fly.

# %%
# Install ipython-sql
# Run the following command just once
# %pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: prettytable in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (9.13.0)
# Requirement already satisfied: sqlalchemy>=2.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (2.0.50)
# Requirement already satisfied: sqlparse in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython->ipython-sql) (5.15.0)
# Requirement already satisfied: wcwidth in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from jedi>=0.18.2->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure_eval in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Installing collected packages: ipython-sql
# Successfully installed ipython-sql-0.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the SQL toolset extension
# %pip uninstall -y sql
# %pip install sql 2022.4.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping sql as it is not installed.
# Collecting sql
#   Downloading sql-2022.4.0.tar.gz (4.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement 2022.4.0 (from versions: none)
# ERROR: No matching distribution found for 2022.4.0

# %% [markdown]
# **Note on Syntax:** The three slashes (///) indicate a relative path. This explicitly tells Jupyter to create the database file in the exact same folder directory where your current notebook file (.ipynb) is running.

# %%
#2. Connect to (and create) the database file
# %sql sqlite:///test_magic.db
# Out:
# UsageError: Line magic function `%sql` not found.

# %% [markdown]
# ### Create the table AUTHORS

# %%
# %%sql
# CREATE TABLE authors (
#     author_id INTEGER PRIMARY KEY AUTOINCREMENT,
#     first_name TEXT NOT NULL,
#     last_name TEXT NOT NULL,
#     biography TEXT
# );
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ### Create the table BOOKS

# %%
# %%sql
# CREATE TABLE books (
#     book_id INTEGER PRIMARY KEY AUTOINCREMENT,
#     title TEXT NOT NULL,
#     isbn TEXT NOT NULL UNIQUE CHECK(length(isbn) BETWEEN 10 AND 13),
#     price REAL NOT NULL CHECK(price >= 0.0),
#     stock_quantity INTEGER NOT NULL DEFAULT 0 CHECK(stock_quantity >= 0)
# );
# Out:
#  * sqlite:///test_magic.db
# Done.
# []

# %%
# %pip install ipython-sql==0.4.1
# Out:
# Collecting ipython-sql==0.4.1
#   Downloading ipython_sql-0.4.1-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable<1 (from ipython-sql==0.4.1)
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: ipython>=1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql==0.4.1) (9.13.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql==0.4.1) (2.0.50)
# Requirement already satisfied: sqlparse in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql==0.4.1) (0.5.5)
# Requirement already satisfied: six in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql==0.4.1) (1.17.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.15.0)
# Requirement already satisfied: wcwidth in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=1.0->ipython-sql==0.4.1) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from jedi>=0.18.2->ipython>=1.0->ipython-sql==0.4.1) (0.8.7)
# Requirement already satisfied: greenlet>=1 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (4.15.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1) (3.0.1)
# Requirement already satisfied: pure_eval in C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1) (0.2.3)
# Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (pyproject.toml): started
#   Building wheel for prettytable (pyproject.toml): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13768 sha256=a3c5c4ed630feb7ae33ffde6bab2e4cd32a3d1bcb422265d54583b715ff7f4fa
#   Stored in directory: c:\users\jacly\appdata\local\pip\cache\wheels\ca\f9\66\1ebeb8cdff2211eebb6fce02957f9e0a9ae3da4b7e65512d1b
# Successfully built prettytable
# Installing collected packages: prettytable, ipython-sql
#
#   Attempting uninstall: prettytable
#
#     Found existing installation: prettytable 3.17.0
#
#     Uninstalling prettytable-3.17.0:
#
#       Successfully uninstalled prettytable-3.17.0
#
#   Attempting uninstall: ipython-sql
#
#     Found existing installation: ipython-sql 0.5.0
#
#     Uninstalling ipython-sql-0.5.0:
#
#       Successfully uninstalled ipython-sql-0.5.0
#
#    -------------------- ------------------- 1/2 [ipython-sql]
#    ---------------------------------------- 2/2 [ipython-sql]
#
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupysql 0.11.1 requires prettytable>=3.12.0, but you have prettytable 0.7.2 which is incompatible.

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~\miniconda3\envs\dab_ds\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\__init__.py:1
# ----> 1 from .magic import *
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\magic.py:16
#      13 from IPython.display import display_javascript
#      14 from sqlalchemy.exc import OperationalError, ProgrammingError, DatabaseError
# ---> 16 import sql.connection
#      17 import sql.parse
#      18 import sql.run
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\__init__.py:1
# ----> 1 from sql.connection.connection import (
#       2     ConnectionManager,
#       3     SQLAlchemyConnection,
#       4     DBAPIConnection,
#       5     SparkConnectConnection,
#       6     is_pep249_compliant,
#       7     is_spark,
#       8     PLOOMBER_DOCS_LINK_STR,
#       9     default_alias_for_engine,
#      10     ResultSetCollection,
#      11     detect_duckdb_summarize_or_select,
#      12 )
#      15 __all__ = [
#      16     "ConnectionManager",
#      17     "SQLAlchemyConnection",
#    (...)     25     "detect_duckdb_summarize_or_select",
#      26 ]
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\connection.py:30
#      28 from sql import exceptions, display
#      29 from sql.error_handler import handle_exception
# ---> 30 from sql.parse import (
#      31     escape_string_literals_with_colon_prefix,
#      32     find_named_parameters,
#      33     ConnectionsFile,
#      34 )
#      35 from sql.warnings import JupySQLQuotedNamedParametersWarning, JupySQLRollbackPerformed
#      36 from sql import _current
#
# ImportError: cannot import name 'escape_string_literals_with_colon_prefix' from 'sql.parse' (C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\sql\parse.py)

# %% [markdown]
# ### Insert values into the AUTHORS table

# %%
# %%sql
# INSERT INTO authors (first_name, last_name, biography)
# VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor.');
#
# INSERT INTO authors (first_name, last_name, biography)
# VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# List all active connections
# %sql -l
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~\miniconda3\envs\dab_ds\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\__init__.py:1
# ----> 1 from .magic import *
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\magic.py:16
#      13 from IPython.display import display_javascript
#      14 from sqlalchemy.exc import OperationalError, ProgrammingError, DatabaseError
# ---> 16 import sql.connection
#      17 import sql.parse
#      18 import sql.run
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\__init__.py:1
# ----> 1 from sql.connection.connection import (
#       2     ConnectionManager,
#       3     SQLAlchemyConnection,
#       4     DBAPIConnection,
#       5     SparkConnectConnection,
#       6     is_pep249_compliant,
#       7     is_spark,
#       8     PLOOMBER_DOCS_LINK_STR,
#       9     default_alias_for_engine,
#      10     ResultSetCollection,
#      11     detect_duckdb_summarize_or_select,
#      12 )
#      15 __all__ = [
#      16     "ConnectionManager",
#      17     "SQLAlchemyConnection",
#    (...)     25     "detect_duckdb_summarize_or_select",
#      26 ]
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\connection.py:30
#      28 from sql import exceptions, display
#      29 from sql.error_handler import handle_exception
# ---> 30 from sql.parse import (
#      31     escape_string_literals_with_colon_prefix,
#      32     find_named_parameters,
#      33     ConnectionsFile,
#      34 )
#      35 from sql.warnings import JupySQLQuotedNamedParametersWarning, JupySQLRollbackPerformed
#      36 from sql import _current
#
# ImportError: cannot import name 'escape_string_literals_with_colon_prefix' from 'sql.parse' (C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\sql\parse.py)

# %%
# %pip install ipython-sql==0.4.1 SQLAlchemy==1.4.49 prettytable==0.7.2 --force-reinstall
# Out:
# Collecting ipython-sql==0.4.1
#   Using cached ipython_sql-0.4.1-py3-none-any.whl.metadata (17 kB)
# Collecting SQLAlchemy==1.4.49
#   Downloading SQLAlchemy-1.4.49-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting prettytable==0.7.2
#   Using cached prettytable-0.7.2-py3-none-any.whl
# Collecting ipython>=1.0 (from ipython-sql==0.4.1)
#   Downloading ipython-9.14.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting sqlparse (from ipython-sql==0.4.1)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting six (from ipython-sql==0.4.1)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting ipython-genutils>=0.1.0 (from ipython-sql==0.4.1)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet!=0.4.17 (from SQLAlchemy==1.4.49)
#   Using cached greenlet-3.5.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting colorama>=0.4.4 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator>=5.1.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Downloading decorator-5.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Collecting matplotlib-inline>=0.1.6 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached matplotlib_inline-0.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting psutil>=7 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting pygments>=2.14.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Downloading traitlets-5.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=1.0->ipython-sql==0.4.1)
#   Downloading wcwidth-0.8.0-py3-none-any.whl.metadata (42 kB)
# Collecting parso<0.9.0,>=0.8.6 (from jedi>=0.18.2->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached parso-0.8.7-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Downloading SQLAlchemy-1.4.49-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 52.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 52.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 52.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 52.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 52.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.2 MB/s  0:00:01
# Using cached greenlet-3.5.1-cp312-cp312-win_amd64.whl (238 kB)
# Downloading ipython-9.14.1-py3-none-any.whl (627 kB)
#    ---------------------------------------- 0.0/627.8 kB ? eta -:--:--
#    ---------------------------------------- 627.8/627.8 kB 11.8 MB/s  0:00:00
# Using cached prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading decorator-5.3.1-py3-none-any.whl (10 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
# Using cached parso-0.8.7-py2.py3-none-any.whl (107 kB)
# Using cached matplotlib_inline-0.2.2-py3-none-any.whl (9.5 kB)
# Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl (137 kB)
# Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.1-py3-none-any.whl (27 kB)
# Using cached executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading traitlets-5.15.1-py3-none-any.whl (85 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Downloading wcwidth-0.8.0-py3-none-any.whl (324 kB)
# Installing collected packages: pure-eval, prettytable, ipython-genutils, wcwidth, traitlets, sqlparse, six, pygments, psutil, parso, greenlet, executing, decorator, colorama, asttokens, stack_data, SQLAlchemy, prompt_toolkit, matplotlib-inline, jedi, ipython-pygments-lexers, ipython, ipython-sql
#
#   Attempting uninstall: pure-eval
#
#     Found existing installation: pure_eval 0.2.3
#
#     Uninstalling pure_eval-0.2.3:
#
#       Successfully uninstalled pure_eval-0.2.3
#
#   Attempting uninstall: prettytable
#
#     Found existing installation: prettytable 0.7.2
#
#     Uninstalling prettytable-0.7.2:
#
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#       Successfully uninstalled prettytable-0.7.2
#    - --------------------------------------  1/23 [prettytable]
#    - --------------------------------------  1/23 [prettytable]
#   Attempting uninstall: ipython-genutils
#    - --------------------------------------  1/23 [prettytable]
#     Found existing installation: ipython-genutils 0.2.0
#    - --------------------------------------  1/23 [prettytable]
#     Uninstalling ipython-genutils-0.2.0:
#    - --------------------------------------  1/23 [prettytable]
#       Successfully uninstalled ipython-genutils-0.2.0
#    - --------------------------------------  1/23 [prettytable]
#    --- ------------------------------------  2/23 [ipython-genutils]
#   Attempting uninstall: wcwidth
#    --- ------------------------------------  2/23 [ipython-genutils]
#     Found existing installation: wcwidth 0.7.0
#    --- ------------------------------------  2/23 [ipython-genutils]
#     Uninstalling wcwidth-0.7.0:
#    --- ------------------------------------  2/23 [ipython-genutils]
#       Successfully uninstalled wcwidth-0.7.0
#    --- ------------------------------------  2/23 [ipython-genutils]
#    ----- ----------------------------------  3/23 [wcwidth]
#    ----- ----------------------------------  3/23 [wcwidth]
#    ----- ----------------------------------  3/23 [wcwidth]
#    ----- ----------------------------------  3/23 [wcwidth]
#    ----- ----------------------------------  3/23 [wcwidth]
#   Attempting uninstall: traitlets
#    ----- ----------------------------------  3/23 [wcwidth]
#     Found existing installation: traitlets 5.15.0
#    ----- ----------------------------------  3/23 [wcwidth]
#     Uninstalling traitlets-5.15.0:
#    ----- ----------------------------------  3/23 [wcwidth]
#       Successfully uninstalled traitlets-5.15.0
#    ----- ----------------------------------  3/23 [wcwidth]
#    ------ ---------------------------------  4/23 [traitlets]
#    ------ ---------------------------------  4/23 [traitlets]
#   Attempting uninstall: sqlparse
#    ------ ---------------------------------  4/23 [traitlets]
#     Found existing installation: sqlparse 0.5.5
#    ------ ---------------------------------  4/23 [traitlets]
#     Uninstalling sqlparse-0.5.5:
#    ------ ---------------------------------  4/23 [traitlets]
#       Successfully uninstalled sqlparse-0.5.5
#    ------ ---------------------------------  4/23 [traitlets]
#    -------- -------------------------------  5/23 [sqlparse]
#    -------- -------------------------------  5/23 [sqlparse]
#   Attempting uninstall: six
#    -------- -------------------------------  5/23 [sqlparse]
#     Found existing installation: six 1.17.0
#    -------- -------------------------------  5/23 [sqlparse]
#     Uninstalling six-1.17.0:
#    -------- -------------------------------  5/23 [sqlparse]
#    ---------- -----------------------------  6/23 [six]
#    ---------- -----------------------------  6/23 [six]
#    ---------- -----------------------------  6/23 [six]
#       Successfully uninstalled six-1.17.0
#    ---------- -----------------------------  6/23 [six]
#   Attempting uninstall: pygments
#    ---------- -----------------------------  6/23 [six]
#    ------------ ---------------------------  7/23 [pygments]
#     Found existing installation: Pygments 2.20.0
#    ------------ ---------------------------  7/23 [pygments]
#     Uninstalling Pygments-2.20.0:
#    ------------ ---------------------------  7/23 [pygments]
#       Successfully uninstalled Pygments-2.20.0
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#   Attempting uninstall: psutil
#    ------------ ---------------------------  7/23 [pygments]
#     Found existing installation: psutil 7.2.2
#    ------------ ---------------------------  7/23 [pygments]
#     Uninstalling psutil-7.2.2:
#    ------------ ---------------------------  7/23 [pygments]
#       Successfully uninstalled psutil-7.2.2
#    ------------ ---------------------------  7/23 [pygments]
#    ------------- --------------------------  8/23 [psutil]
#   Attempting uninstall: parso
#    ------------- --------------------------  8/23 [psutil]
#     Found existing installation: parso 0.8.7
#    ------------- --------------------------  8/23 [psutil]
#     Uninstalling parso-0.8.7:
#    ------------- --------------------------  8/23 [psutil]
#       Successfully uninstalled parso-0.8.7
#    ------------- --------------------------  8/23 [psutil]
#    --------------- ------------------------  9/23 [parso]
#    --------------- ------------------------  9/23 [parso]
#   Attempting uninstall: greenlet
#    --------------- ------------------------  9/23 [parso]
#     Found existing installation: greenlet 3.5.1
#    --------------- ------------------------  9/23 [parso]
#     Uninstalling greenlet-3.5.1:
#    --------------- ------------------------  9/23 [parso]
#       Successfully uninstalled greenlet-3.5.1
#    --------------- ------------------------  9/23 [parso]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#   Attempting uninstall: executing
#    ----------------- ---------------------- 10/23 [greenlet]
#     Found existing installation: executing 2.2.1
#    ----------------- ---------------------- 10/23 [greenlet]
#     Uninstalling executing-2.2.1:
#    ----------------- ---------------------- 10/23 [greenlet]
#       Successfully uninstalled executing-2.2.1
#    ----------------- ---------------------- 10/23 [greenlet]
#    ------------------- -------------------- 11/23 [executing]
#   Attempting uninstall: decorator
#    ------------------- -------------------- 11/23 [executing]
#     Found existing installation: decorator 5.2.1
#    ------------------- -------------------- 11/23 [executing]
#     Uninstalling decorator-5.2.1:
#    ------------------- -------------------- 11/23 [executing]
#    -------------------- ------------------- 12/23 [decorator]
#    -------------------- ------------------- 12/23 [decorator]
#    -------------------- ------------------- 12/23 [decorator]
#       Successfully uninstalled decorator-5.2.1
#    -------------------- ------------------- 12/23 [decorator]
#   Attempting uninstall: colorama
#    -------------------- ------------------- 12/23 [decorator]
#     Found existing installation: colorama 0.4.6
#    -------------------- ------------------- 12/23 [decorator]
#     Uninstalling colorama-0.4.6:
#    -------------------- ------------------- 12/23 [decorator]
#       Successfully uninstalled colorama-0.4.6
#    -------------------- ------------------- 12/23 [decorator]
#    ---------------------- ----------------- 13/23 [colorama]
#   Attempting uninstall: asttokens
#    ---------------------- ----------------- 13/23 [colorama]
#     Found existing installation: asttokens 3.0.1
#    ---------------------- ----------------- 13/23 [colorama]
#     Uninstalling asttokens-3.0.1:
#    ---------------------- ----------------- 13/23 [colorama]
#       Successfully uninstalled asttokens-3.0.1
#    ---------------------- ----------------- 13/23 [colorama]
#    ------------------------ --------------- 14/23 [asttokens]
#   Attempting uninstall: stack_data
#    ------------------------ --------------- 14/23 [asttokens]
#     Found existing installation: stack_data 0.6.3
#    ------------------------ --------------- 14/23 [asttokens]
#     Uninstalling stack_data-0.6.3:
#    ------------------------ --------------- 14/23 [asttokens]
#       Successfully uninstalled stack_data-0.6.3
#    ------------------------ --------------- 14/23 [asttokens]
#    -------------------------- ------------- 15/23 [stack_data]
#   Attempting uninstall: SQLAlchemy
#    -------------------------- ------------- 15/23 [stack_data]
#     Found existing installation: SQLAlchemy 2.0.50
#    -------------------------- ------------- 15/23 [stack_data]
#     Uninstalling SQLAlchemy-2.0.50:
#    -------------------------- ------------- 15/23 [stack_data]
#       Successfully uninstalled SQLAlchemy-2.0.50
#    -------------------------- ------------- 15/23 [stack_data]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#   Attempting uninstall: prompt_toolkit
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#     Found existing installation: prompt_toolkit 3.0.52
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Uninstalling prompt_toolkit-3.0.52:
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#       Successfully uninstalled prompt_toolkit-3.0.52
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#   Attempting uninstall: matplotlib-inline
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Found existing installation: matplotlib-inline 0.2.2
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Uninstalling matplotlib-inline-0.2.2:
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#       Successfully uninstalled matplotlib-inline-0.2.2
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ------------------------------- -------- 18/23 [matplotlib-inline]
#   Attempting uninstall: jedi
#    ------------------------------- -------- 18/23 [matplotlib-inline]
#     Found existing installation: jedi 0.19.2
#    ------------------------------- -------- 18/23 [matplotlib-inline]
#    --------------------------------- ------ 19/23 [jedi]
#     Uninstalling jedi-0.19.2:
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#       Successfully uninstalled jedi-0.19.2
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#   Attempting uninstall: ipython-pygments-lexers
#    --------------------------------- ------ 19/23 [jedi]
#     Found existing installation: ipython_pygments_lexers 1.1.1
#    --------------------------------- ------ 19/23 [jedi]
#     Uninstalling ipython_pygments_lexers-1.1.1:
#    --------------------------------- ------ 19/23 [jedi]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#       Successfully uninstalled ipython_pygments_lexers-1.1.1
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#   Attempting uninstall: ipython
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#     Found existing installation: ipython 9.13.0
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#     Uninstalling ipython-9.13.0:
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ------------------------------------ --- 21/23 [ipython]
#       Successfully uninstalled ipython-9.13.0
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#   Attempting uninstall: ipython-sql
#    ------------------------------------ --- 21/23 [ipython]
#     Found existing installation: ipython-sql 0.4.1
#    ------------------------------------ --- 21/23 [ipython]
#     Uninstalling ipython-sql-0.4.1:
#    ------------------------------------ --- 21/23 [ipython]
#       Successfully uninstalled ipython-sql-0.4.1
#    ------------------------------------ --- 21/23 [ipython]
#    -------------------------------------- - 22/23 [ipython-sql]
#    ---------------------------------------- 23/23 [ipython-sql]
#
# Successfully installed SQLAlchemy-1.4.49 asttokens-3.0.1 colorama-0.4.6 decorator-5.3.1 executing-2.2.1 greenlet-3.5.1 ipython-9.14.1 ipython-genutils-0.2.0 ipython-pygments-lexers-1.1.1 ipython-sql-0.4.1 jedi-0.20.0 matplotlib-inline-0.2.2 parso-0.8.7 prettytable-0.7.2 prompt_toolkit-3.0.52 psutil-7.2.2 pure-eval-0.2.3 pygments-2.20.0 six-1.17.0 sqlparse-0.5.5 stack_data-0.6.3 traitlets-5.15.1 wcwidth-0.8.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\~reenlet'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\~qlalchemy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupysql 0.11.1 requires prettytable>=3.12.0, but you have prettytable 0.7.2 which is incompatible.

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~\miniconda3\envs\dab_ds\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\__init__.py:1
# ----> 1 from .magic import *
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\magic.py:16
#      13 from IPython.display import display_javascript
#      14 from sqlalchemy.exc import OperationalError, ProgrammingError, DatabaseError
# ---> 16 import sql.connection
#      17 import sql.parse
#      18 import sql.run
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\__init__.py:1
# ----> 1 from sql.connection.connection import (
#       2     ConnectionManager,
#       3     SQLAlchemyConnection,
#       4     DBAPIConnection,
#       5     SparkConnectConnection,
#       6     is_pep249_compliant,
#       7     is_spark,
#       8     PLOOMBER_DOCS_LINK_STR,
#       9     default_alias_for_engine,
#      10     ResultSetCollection,
#      11     detect_duckdb_summarize_or_select,
#      12 )
#      15 __all__ = [
#      16     "ConnectionManager",
#      17     "SQLAlchemyConnection",
#    (...)     25     "detect_duckdb_summarize_or_select",
#      26 ]
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\connection.py:30
#      28 from sql import exceptions, display
#      29 from sql.error_handler import handle_exception
# ---> 30 from sql.parse import (
#      31     escape_string_literals_with_colon_prefix,
#      32     find_named_parameters,
#      33     ConnectionsFile,
#      34 )
#      35 from sql.warnings import JupySQLQuotedNamedParametersWarning, JupySQLRollbackPerformed
#      36 from sql import _current
#
# ImportError: cannot import name 'escape_string_literals_with_colon_prefix' from 'sql.parse' (C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\sql\parse.py)

# %%
# %sql sqlite:///test_magic.db
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %pip install ipython-sql==0.4.1 SQLAlchemy==1.4.49 prettytable==0.7.2 --force-reinstall
# Out:
# Collecting ipython-sql==0.4.1
#   Using cached ipython_sql-0.4.1-py3-none-any.whl.metadata (17 kB)
# Collecting SQLAlchemy==1.4.49
#   Using cached SQLAlchemy-1.4.49-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting prettytable==0.7.2
#   Using cached prettytable-0.7.2-py3-none-any.whl
# Collecting ipython>=1.0 (from ipython-sql==0.4.1)
#   Using cached ipython-9.14.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting sqlparse (from ipython-sql==0.4.1)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting six (from ipython-sql==0.4.1)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting ipython-genutils>=0.1.0 (from ipython-sql==0.4.1)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet!=0.4.17 (from SQLAlchemy==1.4.49)
#   Using cached greenlet-3.5.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting colorama>=0.4.4 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator>=5.1.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached decorator-5.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Collecting matplotlib-inline>=0.1.6 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached matplotlib_inline-0.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting psutil>=7 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting pygments>=2.14.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=1.0->ipython-sql==0.4.1)
#   Using cached traitlets-5.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached wcwidth-0.8.0-py3-none-any.whl.metadata (42 kB)
# Collecting parso<0.9.0,>=0.8.6 (from jedi>=0.18.2->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached parso-0.8.7-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=1.0->ipython-sql==0.4.1)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Using cached SQLAlchemy-1.4.49-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached greenlet-3.5.1-cp312-cp312-win_amd64.whl (238 kB)
# Using cached ipython-9.14.1-py3-none-any.whl (627 kB)
# Using cached prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.3.1-py3-none-any.whl (10 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
# Using cached parso-0.8.7-py2.py3-none-any.whl (107 kB)
# Using cached matplotlib_inline-0.2.2-py3-none-any.whl (9.5 kB)
# Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl (137 kB)
# Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.1-py3-none-any.whl (27 kB)
# Using cached executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Using cached traitlets-5.15.1-py3-none-any.whl (85 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached wcwidth-0.8.0-py3-none-any.whl (324 kB)
# Installing collected packages: pure-eval, prettytable, ipython-genutils, wcwidth, traitlets, sqlparse, six, pygments, psutil, parso, greenlet, executing, decorator, colorama, asttokens, stack_data, SQLAlchemy, prompt_toolkit, matplotlib-inline, jedi, ipython-pygments-lexers, ipython, ipython-sql
#
#   Attempting uninstall: pure-eval
#
#     Found existing installation: pure_eval 0.2.3
#
#     Uninstalling pure_eval-0.2.3:
#
#       Successfully uninstalled pure_eval-0.2.3
#
#   Attempting uninstall: prettytable
#
#     Found existing installation: prettytable 0.7.2
#
#     Uninstalling prettytable-0.7.2:
#
#    - --------------------------------------  1/23 [prettytable]
#       Successfully uninstalled prettytable-0.7.2
#    - --------------------------------------  1/23 [prettytable]
#   Attempting uninstall: ipython-genutils
#    - --------------------------------------  1/23 [prettytable]
#     Found existing installation: ipython-genutils 0.2.0
#    - --------------------------------------  1/23 [prettytable]
#     Uninstalling ipython-genutils-0.2.0:
#    - --------------------------------------  1/23 [prettytable]
#       Successfully uninstalled ipython-genutils-0.2.0
#    - --------------------------------------  1/23 [prettytable]
#    --- ------------------------------------  2/23 [ipython-genutils]
#   Attempting uninstall: wcwidth
#    --- ------------------------------------  2/23 [ipython-genutils]
#     Found existing installation: wcwidth 0.8.0
#    --- ------------------------------------  2/23 [ipython-genutils]
#     Uninstalling wcwidth-0.8.0:
#    --- ------------------------------------  2/23 [ipython-genutils]
#       Successfully uninstalled wcwidth-0.8.0
#    --- ------------------------------------  2/23 [ipython-genutils]
#    ----- ----------------------------------  3/23 [wcwidth]
#    ----- ----------------------------------  3/23 [wcwidth]
#   Attempting uninstall: traitlets
#    ----- ----------------------------------  3/23 [wcwidth]
#     Found existing installation: traitlets 5.15.1
#    ----- ----------------------------------  3/23 [wcwidth]
#     Uninstalling traitlets-5.15.1:
#    ----- ----------------------------------  3/23 [wcwidth]
#       Successfully uninstalled traitlets-5.15.1
#    ----- ----------------------------------  3/23 [wcwidth]
#    ------ ---------------------------------  4/23 [traitlets]
#   Attempting uninstall: sqlparse
#    ------ ---------------------------------  4/23 [traitlets]
#     Found existing installation: sqlparse 0.5.5
#    ------ ---------------------------------  4/23 [traitlets]
#    -------- -------------------------------  5/23 [sqlparse]
#     Uninstalling sqlparse-0.5.5:
#    -------- -------------------------------  5/23 [sqlparse]
#       Successfully uninstalled sqlparse-0.5.5
#    -------- -------------------------------  5/23 [sqlparse]
#   Attempting uninstall: six
#    -------- -------------------------------  5/23 [sqlparse]
#    ---------- -----------------------------  6/23 [six]
#     Found existing installation: six 1.17.0
#    ---------- -----------------------------  6/23 [six]
#     Uninstalling six-1.17.0:
#    ---------- -----------------------------  6/23 [six]
#    ---------- -----------------------------  6/23 [six]
#       Successfully uninstalled six-1.17.0
#    ---------- -----------------------------  6/23 [six]
#   Attempting uninstall: pygments
#    ---------- -----------------------------  6/23 [six]
#     Found existing installation: Pygments 2.20.0
#    ---------- -----------------------------  6/23 [six]
#     Uninstalling Pygments-2.20.0:
#    ---------- -----------------------------  6/23 [six]
#       Successfully uninstalled Pygments-2.20.0
#    ---------- -----------------------------  6/23 [six]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#    ------------ ---------------------------  7/23 [pygments]
#   Attempting uninstall: psutil
#    ------------ ---------------------------  7/23 [pygments]
#     Found existing installation: psutil 7.2.2
#    ------------ ---------------------------  7/23 [pygments]
#     Uninstalling psutil-7.2.2:
#    ------------ ---------------------------  7/23 [pygments]
#       Successfully uninstalled psutil-7.2.2
#    ------------ ---------------------------  7/23 [pygments]
#    ------------- --------------------------  8/23 [psutil]
#   Attempting uninstall: parso
#    ------------- --------------------------  8/23 [psutil]
#     Found existing installation: parso 0.8.7
#    ------------- --------------------------  8/23 [psutil]
#     Uninstalling parso-0.8.7:
#    ------------- --------------------------  8/23 [psutil]
#       Successfully uninstalled parso-0.8.7
#    ------------- --------------------------  8/23 [psutil]
#    --------------- ------------------------  9/23 [parso]
#    --------------- ------------------------  9/23 [parso]
#   Attempting uninstall: greenlet
#    --------------- ------------------------  9/23 [parso]
#     Found existing installation: greenlet 3.5.1
#    --------------- ------------------------  9/23 [parso]
#     Uninstalling greenlet-3.5.1:
#    --------------- ------------------------  9/23 [parso]
#    ----------------- ---------------------- 10/23 [greenlet]
#       Successfully uninstalled greenlet-3.5.1
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#    ----------------- ---------------------- 10/23 [greenlet]
#   Attempting uninstall: executing
#    ----------------- ---------------------- 10/23 [greenlet]
#     Found existing installation: executing 2.2.1
#    ----------------- ---------------------- 10/23 [greenlet]
#     Uninstalling executing-2.2.1:
#    ----------------- ---------------------- 10/23 [greenlet]
#       Successfully uninstalled executing-2.2.1
#    ----------------- ---------------------- 10/23 [greenlet]
#    ------------------- -------------------- 11/23 [executing]
#   Attempting uninstall: decorator
#    ------------------- -------------------- 11/23 [executing]
#     Found existing installation: decorator 5.3.1
#    ------------------- -------------------- 11/23 [executing]
#     Uninstalling decorator-5.3.1:
#    ------------------- -------------------- 11/23 [executing]
#       Successfully uninstalled decorator-5.3.1
#    ------------------- -------------------- 11/23 [executing]
#   Attempting uninstall: colorama
#    ------------------- -------------------- 11/23 [executing]
#     Found existing installation: colorama 0.4.6
#    ------------------- -------------------- 11/23 [executing]
#     Uninstalling colorama-0.4.6:
#    ------------------- -------------------- 11/23 [executing]
#       Successfully uninstalled colorama-0.4.6
#    ------------------- -------------------- 11/23 [executing]
#    ---------------------- ----------------- 13/23 [colorama]
#   Attempting uninstall: asttokens
#    ---------------------- ----------------- 13/23 [colorama]
#     Found existing installation: asttokens 3.0.1
#    ---------------------- ----------------- 13/23 [colorama]
#     Uninstalling asttokens-3.0.1:
#    ---------------------- ----------------- 13/23 [colorama]
#    ------------------------ --------------- 14/23 [asttokens]
#       Successfully uninstalled asttokens-3.0.1
#    ------------------------ --------------- 14/23 [asttokens]
#   Attempting uninstall: stack_data
#    ------------------------ --------------- 14/23 [asttokens]
#     Found existing installation: stack-data 0.6.3
#    ------------------------ --------------- 14/23 [asttokens]
#     Uninstalling stack-data-0.6.3:
#    ------------------------ --------------- 14/23 [asttokens]
#       Successfully uninstalled stack-data-0.6.3
#    ------------------------ --------------- 14/23 [asttokens]
#    -------------------------- ------------- 15/23 [stack_data]
#   Attempting uninstall: SQLAlchemy
#    -------------------------- ------------- 15/23 [stack_data]
#     Found existing installation: SQLAlchemy 1.4.49
#    -------------------------- ------------- 15/23 [stack_data]
#     Uninstalling SQLAlchemy-1.4.49:
#    -------------------------- ------------- 15/23 [stack_data]
#       Successfully uninstalled SQLAlchemy-1.4.49
#    -------------------------- ------------- 15/23 [stack_data]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#   Attempting uninstall: prompt_toolkit
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#     Found existing installation: prompt_toolkit 3.0.52
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#     Uninstalling prompt_toolkit-3.0.52:
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#       Successfully uninstalled prompt_toolkit-3.0.52
#    --------------------------- ------------ 16/23 [SQLAlchemy]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#   Attempting uninstall: matplotlib-inline
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Found existing installation: matplotlib-inline 0.2.2
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Uninstalling matplotlib-inline-0.2.2:
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#       Successfully uninstalled matplotlib-inline-0.2.2
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#   Attempting uninstall: jedi
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#     Found existing installation: jedi 0.20.0
#    ----------------------------- ---------- 17/23 [prompt_toolkit]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#     Uninstalling jedi-0.20.0:
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#       Successfully uninstalled jedi-0.20.0
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#    --------------------------------- ------ 19/23 [jedi]
#   Attempting uninstall: ipython-pygments-lexers
#    --------------------------------- ------ 19/23 [jedi]
#     Found existing installation: ipython_pygments_lexers 1.1.1
#    --------------------------------- ------ 19/23 [jedi]
#     Uninstalling ipython_pygments_lexers-1.1.1:
#    --------------------------------- ------ 19/23 [jedi]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#       Successfully uninstalled ipython_pygments_lexers-1.1.1
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#   Attempting uninstall: ipython
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#     Found existing installation: ipython 9.14.1
#    ---------------------------------- ----- 20/23 [ipython-pygments-lexers]
#    ------------------------------------ --- 21/23 [ipython]
#     Uninstalling ipython-9.14.1:
#    ------------------------------------ --- 21/23 [ipython]
#       Successfully uninstalled ipython-9.14.1
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#    ------------------------------------ --- 21/23 [ipython]
#   Attempting uninstall: ipython-sql
#    ------------------------------------ --- 21/23 [ipython]
#     Found existing installation: ipython-sql 0.4.1
#    ------------------------------------ --- 21/23 [ipython]
#     Uninstalling ipython-sql-0.4.1:
#    ------------------------------------ --- 21/23 [ipython]
#       Successfully uninstalled ipython-sql-0.4.1
#    ------------------------------------ --- 21/23 [ipython]
#    -------------------------------------- - 22/23 [ipython-sql]
#    ---------------------------------------- 23/23 [ipython-sql]
#
# Successfully installed SQLAlchemy-1.4.49 asttokens-3.0.1 colorama-0.4.6 decorator-5.3.1 executing-2.2.1 greenlet-3.5.1 ipython-9.14.1 ipython-genutils-0.2.0 ipython-pygments-lexers-1.1.1 ipython-sql-0.4.1 jedi-0.20.0 matplotlib-inline-0.2.2 parso-0.8.7 prettytable-0.7.2 prompt_toolkit-3.0.52 psutil-7.2.2 pure-eval-0.2.3 pygments-2.20.0 six-1.17.0 sqlparse-0.5.5 stack_data-0.6.3 traitlets-5.15.1 wcwidth-0.8.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupysql 0.11.1 requires prettytable>=3.12.0, but you have prettytable 0.7.2 which is incompatible.

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~\miniconda3\envs\dab_ds\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\__init__.py:1
# ----> 1 from .magic import *
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\magic.py:16
#      13 from IPython.display import display_javascript
#      14 from sqlalchemy.exc import OperationalError, ProgrammingError, DatabaseError
# ---> 16 import sql.connection
#      17 import sql.parse
#      18 import sql.run
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\__init__.py:1
# ----> 1 from sql.connection.connection import (
#       2     ConnectionManager,
#       3     SQLAlchemyConnection,
#       4     DBAPIConnection,
#       5     SparkConnectConnection,
#       6     is_pep249_compliant,
#       7     is_spark,
#       8     PLOOMBER_DOCS_LINK_STR,
#       9     default_alias_for_engine,
#      10     ResultSetCollection,
#      11     detect_duckdb_summarize_or_select,
#      12 )
#      15 __all__ = [
#      16     "ConnectionManager",
#      17     "SQLAlchemyConnection",
#    (...)     25     "detect_duckdb_summarize_or_select",
#      26 ]
#
# File ~\miniconda3\envs\dab_ds\Lib\site-packages\sql\connection\connection.py:30
#      28 from sql import exceptions, display
#      29 from sql.error_handler import handle_exception
# ---> 30 from sql.parse import (
#      31     escape_string_literals_with_colon_prefix,
#      32     find_named_parameters,
#      33     ConnectionsFile,
#      34 )
#      35 from sql.warnings import JupySQLQuotedNamedParametersWarning, JupySQLRollbackPerformed
#      36 from sql import _current
#
# ImportError: cannot import name 'escape_string_literals_with_colon_prefix' from 'sql.parse' (C:\Users\Jacly\miniconda3\envs\dab_ds\Lib\site-packages\sql\parse.py)

# %%
import sqlite3
conn = sqlite3. connect("test_magic.db")
cursor = conn.cursor()

# %%
cursor.execute("""



INSERT INTO authors (first_name, last_name, biography)



VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');



""")



cursor.execute("""



INSERT INTO authors (first_name, last_name, biography)



VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');



""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cursor.execute("""
#       2
#       3
#       4
#
# OperationalError: no such table: authors

# %%
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');
""")
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
""")

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cursor.execute("""
#       2 INSERT INTO authors (first_name, last_name, biography)
#       3 VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');
#       4 """)
#
# OperationalError: no such table: authors

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS authors (
    author_id INTEGER PRIMARY KEY AUTOINCREMENT,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL,
    biography TEXT
);
""")
conn.commit()

# %%
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');
""")

cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
""")

conn.commit()

# %%
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');
""")
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
""")

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('authors',), ('sqlite_sequence',)]

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS books (
    book_id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    isbn TEXT NOT NULL UNIQUE,
    price REAL NOT NULL CHECK(price >= 0.0),
    stock_quantity INTEGER NOT NULL DEFAULT 0 CHECK(stock_quantity >= 0)
);
""")
conn.commit()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('authors',), ('sqlite_sequence',), ('books',)]

# %%
# %%sql
# INSERT INTO authors (first_name, last_name, biography)
# VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor.');
#
# INSERT INTO authors (first_name, last_name, biography)
# VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
cursor.execute("SELECT * FROM authors")
print(cursor.fetchall())
# Out:
# [(1, 'Milton', 'Mendieta', 'Academic and Data Engineering Instructor'), (2, 'Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.'), (3, 'Milton', 'Mendieta', 'Academic and Data Engineering Instructor'), (4, 'Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.'), (5, 'Milton', 'Mendieta', 'Academic and Data Engineering Instructor'), (6, 'Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.')]

# %%
cursor.execute("DELETE FROM authors")
conn.commit()

# %%
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Milton', 'Mendieta', 'Academic and Data Engineering Instructor');
""")
cursor.execute("""
INSERT INTO authors (first_name, last_name, biography)
VALUES ('Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.');
""")
conn.commit()

# %%
cursor.execute("SELECT * FROM authors")
print(cursor.fetchall())
# Out:
# [(7, 'Milton', 'Mendieta', 'Academic and Data Engineering Instructor'), (8, 'Alan', 'Turing', 'Mathematician, computer scientist, and father of theoretical computer science.')]
